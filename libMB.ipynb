# %%
importnumpyasnp


ID,Merek,Model,Transmisi,BahanBakar,Tahun,Harga,Lok,Web,Web,Web

# %%
 # if editColumn == 'merek':
                            #     database[noUbah][1] = stringValidation(title = 'Masukkan merek mobil baru: ').title()
                            #     printTable(database)
                            #     break
                            # elif editColumn == 'model':
                            #     database[noUbah][2] = stringValidation(title = 'Masukkan model mobil yang baru: ').title()
                            #     printTable(database)
                            #     break
                            # elif editColumn == 'transmisi':
                            #     database[noUbah][3] = stringValidation(title = 'Masukkan transmisi mobil yang baru: ').title()
                            #     printTable(database)
                            #     break
                            # elif editColumn == 'bahan bakar':
                            #     database[noUbah][4] = stringValidation(title = 'Masukkan bahan bakar mobil yang baru: ').title()
                            #     printTable(database)
                            #     break
                            # elif editColumn == 'tahun':
                            #     database[noUbah][5] = integerValidation(title = 'Masukkan tahun mobil yang baru: ')
                            #     printTable(database)
                            #     break
                            # elif editColumn == 'harga':
                            #     database[noUbah][6] = integerValidation(title = 'Masukkan harga mobil yang baru: ')
                            #     printTable(database)
                            #     break
                            # elif editColumn :
                            #     # database[noUbah][editColumn] = stringValidation(title = 'Masukkan data baru: ')
                            #     printTable(database)

                                # newColu = stringValidation('Silakan masukkan data yang ingin Anda tambahkan: ')
                                # idx = HEADERS.get(newColu)
                                # print(database)
                                # database[noUbah][HEADERS.index(editColumn)] = stringValidation(title = 'Masukkan data {} yang baru: '.format(editColumn))
                                # printTable(database)

# %%
elif option in ['y', 'yes', 'ya', 'iya']:
                        while True:
                            for index in range(len(HEADERS)) :
                                idx = index
                                headers = HEADERS[index]
                                print("%i) %s" %(idx+1, headers))
                            editColumn = integerValidation(title = 'Silakan masukkan nomor yang ingin diubah: ')
                            if editColumn - 1 < len(HEADERS):    
                                database[noUbah][editColumn - 1] = input('Masukkan data baru: ')
                                printTable(database)
                                break
                            else:
                                print('''
                                      
                                Kolom tidak tersedia
                                      
                                      ''')
                                break
                        break

# %%
while True:
    for index in range(len(HEADERS)):
        idx = index
        headers = HEADERS[index]
        print("%i) %s" %(idx+1, headers))
        if editColumn - 1 < len(HEADERS):    
            database[:][editColumn - 1] = input('Masukkan data baru: ')
            printTable(database)
            if range(len(headers)):
                printTable(database)
                option = input('Apakah Anda mau menambahkan data ke kolom lain? (y/n)')
                if option == 'y':
                    continue
                else:
                    break
        else:
            print('''
                                      
            kolom tidak tersedia
                                      
            ''')
            break

# %%
def main():
    global db_admin, db_user, db_list_user
    print('Selamat Datang di MoKu - MobilKu - Mobil dan Aku!')

    listMenu = '''
      
      Selamat Datang di MoKu - MobilKu - Mobil dan Aku!

      
      List Menu:
      1. Lihat Daftar Mobil
      2. Tambah Daftar Mobil
      3. Hapus Daftar Mobil
      4. Perbarui Daftar Mobil
      5. Keluar
      '''

    while True:
        print(listMenu)
        option = input('Masukkan angka yang ingin dijalankan: ')

        if option == '1':
            mylib.show(db_admin, db_user)
        elif option == '2':
            mylib.add(db_admin)
        elif option == '3':
            mylib.delete(db_admin)
        elif option == '4':
            mylib.update(db_admin)
        elif option == '5':
            break

# %%
def main():
    global db_admin, db_user, db_list_user
    print('Selamat Datang di MoKu - MobilKu - Mobil dan Aku!')

    listMenu = '''
      
      Selamat Datang di MoKu - MobilKu - Mobil dan Aku!

      
      List Menu:
      1. Admin
      2. Kolaborator
      3. Pembeli
      4. Keluar

      '''
    
    while True:
        print(listMenu)
        option = input('Masukkan angka yang ingin dijalankan: ')

        if option == '1':
            def password():
                print ("Selamat Datang di MoKu - MobilKu - Mobil dan Aku!")
                while True:
                    passw = input("Please enter your Password: ")
                    if passw == '123AbC':
                        return print ('Selamat Datang di MoKu - MobilKu - Mobil dan Aku!')
                    else:
                        print ('Masukkan password yang benar')
                    print('Selamat Datang di MoKu - MobilKu - Mobil dan Aku!')

                    listMenu = '''
                    
                    Selamat Datang di MoKu - MobilKu - Mobil dan Aku!

                    
                    List Menu:
                    1. Lihat Daftar Mobil
                    2. Tambah Daftar Mobil
                    3. Hapus Daftar Mobil
                    4. Perbarui Daftar Mobil
                    5. Keluar
                    '''

                    while True:
                        print(listMenu)
                        option = input('Masukkan angka yang ingin dijalankan: ')

                        if option == '1':
                            mylib.show(db_admin, db_user)
                        elif option == '2':
                            mylib.add(db_admin)
                        elif option == '3':
                            mylib.delete(db_admin)
                        elif option == '4':
                            mylib.update(db_admin)
                        elif option == '5':
                            break


        elif option == '2':
            while True:
                    passw = input("Please enter your Password: ")
                    if passw == '123AbC':
                        return print ('Welcome to hospital database')
                    else:
                        print ('Please Input the right password')
                    print('Selamat Datang di MoKu - MobilKu - Mobil dan Aku!')

                    listMenu = '''
                    
                    Selamat Datang di MoKu - MobilKu - Mobil dan Aku!

                    
                    List Menu:
                    1. Lihat Daftar Mobil
                    2. Tambah Daftar Mobil
                    3. Hapus Daftar Mobil
                    4. Perbarui Daftar Mobil
                    5. Keluar
                    '''

                    while True:
                        print(listMenu)
                        option = input('Masukkan angka yang ingin dijalankan: ')

                        if option == '1':
                            mylib.show(db_admin, db_user)
                        elif option == '2':
                            mylib.add(db_user)
                        elif option == '3':
                            mylib.delete(db_user)
                        elif option == '4':
                            mylib.update(db_user)
                        elif option == '5':
                            break


        elif option == '3':
            print('Selamat Datang di MoKu - MobilKu - Mobil dan Aku!')

            listMenu = '''
                    
            Selamat Datang di MoKu - MobilKu - Mobil dan Aku!

                    
                List Menu:
                1. Lihat Daftar Mobil
                2. Keluar

                '''
            while True:
                print(listMenu)
                option = input('Masukkan angka yang ingin dijalankan: ')
                if option == '1':
                    mylib.show(db_admin, db_user)
                elif option == '2':
                    break


        elif option == '4':
            break
